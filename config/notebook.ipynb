# %%
# !git clone https://github.com/jpmansour-ai-dev/Diffusion
# %cd Diffusion
# %pip install -q datasets
# !python main.py
# Out:
# Cloning into 'Diffusion'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 85 (delta 30), reused 60 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 18.49 KiB | 6.16 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# /content/Diffusion/Diffusion
# Device: cuda
# README.md: 9.28kB [00:00, 24.7MB/s]
# Resolving data files: 100% 19/19 [00:00<00:00, 64737.43it/s]
# ...
# Resolving data files: 100% 19/19 [00:00<00:00, 185761.72it/s]
# ...
# img_align+identity+attr/train-00000-of-0(…):   0% 0.00/500M [00:00<?, ?B/s]
# img_align+identity+attr/train-00000-of-0(…):   0% 0.00/500M [00:00<?, ?B/s]
# img_align+identity+attr/train-00000-of-0(…):   0% 0.00/500M [00:00<?, ?B/s]
# img_align+identity+attr/train-00000-of-0(…):   0% 0.00/500M [00:00<?, ?B/s]
# img_align+identity+attr/train-00000-of-0(…):   0% 0.00/500M [00:00<?, ?B/s]
# ...
